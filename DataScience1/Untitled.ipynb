# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\ibiso\OneDrive\Documents\Countriesxyz\ds_salaries.csv")

df.plot()

plt.show()

# %%
df.plot(kind = 'scatter', x = 'salary_in_usd', y = 'salary' )
plt.show()

# %%
df['work_year'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
