# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\ibiso\OneDrive\Documents\Countriesxyz\world_population_excel_workbook.xlsx")

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df = pd.read_excel(r"C:\Users\ibiso\OneDrive\Documents\Countriesxyz\world_population_excel_workbook.xlsx", index_col = 'Country' )
df
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia         41128771
# Albania             138  ALB            Tirana    Europe          2842321
# Algeria              34  DZA           Algiers    Africa         44903225
# American Samoa      213  ASM         Pago Pago   Oceania            44273
# Andorra             203  AND  Andorra la Vella    Europe            79824
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania            11572
# Western Sahara      172  ESH         El AaiÃºn    Africa           575986
# Yemen                46  YEM             Sanaa      Asia         33696614
# Zambia               63  ZMB            Lusaka    Africa         20017675
# Zimbabwe             74  ZWE            Harare    Africa         16320537
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                Country  level_0  index  Rank CCA3           Capital Continent  \
# 0          Afghanistan        0      0    36  AFG             Kabul      Asia
# 1              Albania        1      1   138  ALB            Tirana    Europe
# 2              Algeria        2      2    34  DZA           Algiers    Africa
# 3       American Samoa        3      3   213  ASM         Pago Pago   Oceania
# 4              Andorra        4      4   203  AND  Andorra la Vella    Europe
# ..                 ...      ...    ...   ...  ...               ...       ...
# 229  Wallis and Futuna      229    229   226  WLF          Mata-Utu   Oceania
# 230     Western Sahara      230    230   172  ESH         El AaiÃºn    Africa
# 231              Yemen      231    231    46  YEM             Sanaa      Asia
# 232             Zambia      232    232    63  ZMB            Lusaka    Africa
# 233           Zimbabwe      233    233    74  ZWE            Harare    Africa
#
# ...

# %%
df.set_index('Country', inplace=True)
df
# Out:
#                    level_0  index  Rank CCA3           Capital Continent  \
# Country
# Afghanistan              0      0    36  AFG             Kabul      Asia
# Albania                  1      1   138  ALB            Tirana    Europe
# Algeria                  2      2    34  DZA           Algiers    Africa
# American Samoa           3      3   213  ASM         Pago Pago   Oceania
# Andorra                  4      4   203  AND  Andorra la Vella    Europe
# ...                    ...    ...   ...  ...               ...       ...
# Wallis and Futuna      229    229   226  WLF          Mata-Utu   Oceania
# Western Sahara         230    230   172  ESH         El AaiÃºn    Africa
# Yemen                  231    231    46  YEM             Sanaa      Asia
# Zambia                 232    232    63  ZMB            Lusaka    Africa
# Zimbabwe               233    233    74  ZWE            Harare    Africa
#
#                    2022 Population  2020 Population  2015 Population  \
# Country
# ...

# %%
df.loc['Zambia']
# Out:
# level_0                             232
# index                               232
# Rank                                 63
# CCA3                                ZMB
# Capital                          Lusaka
# Continent                        Africa
# 2022 Population                20017675
# 2020 Population                18927715
# 2015 Population                16248230
# 2010 Population                13792086
# 2000 Population                 9891136
# 1990 Population                 7686401
# 1980 Population                 5720438
# 1970 Population                 4281671
# Area (kmÂ²)                      752612
# Density (per kmÂ²)              26.5976
# Growth Rate                       1.028
# World Population Percentage        0.25
# Name: Zambia, dtype: object

# %%
df.iloc[232]
# Out:
# level_0                             232
# index                               232
# Rank                                 63
# CCA3                                ZMB
# Capital                          Lusaka
# Continent                        Africa
# 2022 Population                20017675
# 2020 Population                18927715
# 2015 Population                16248230
# 2010 Population                13792086
# 2000 Population                 9891136
# 1990 Population                 7686401
# 1980 Population                 5720438
# 1970 Population                 4281671
# Area (kmÂ²)                      752612
# Density (per kmÂ²)              26.5976
# Growth Rate                       1.028
# World Population Percentage        0.25
# Name: Zambia, dtype: object

# %%
df.reset_index(inplace=True)
df.set_index(['Continent', 'Country'], inplace=True)
df
# Out:
#                              level_0  index  Rank CCA3           Capital  \
# Continent Country
# Asia      Afghanistan              0      0    36  AFG             Kabul
# Europe    Albania                  1      1   138  ALB            Tirana
# Africa    Algeria                  2      2    34  DZA           Algiers
# Oceania   American Samoa           3      3   213  ASM         Pago Pago
# Europe    Andorra                  4      4   203  AND  Andorra la Vella
# ...                              ...    ...   ...  ...               ...
# Oceania   Wallis and Futuna      229    229   226  WLF          Mata-Utu
# Africa    Western Sahara         230    230   172  ESH         El AaiÃºn
# Asia      Yemen                  231    231    46  YEM             Sanaa
# Africa    Zambia                 232    232    63  ZMB            Lusaka
#           Zimbabwe               233    233    74  ZWE            Harare
#
#                              2022 Population  2020 Population  \
# ...

# %%
df.sort_index(ascending=False)
#pd.set_option('display.max.columns',235)
# Out:
#                             level_0  index  Rank CCA3      Capital  \
# Continent     Country
# South America Venezuela         227    227    51  VEN      Caracas
#               Uruguay           223    223   133  URY   Montevideo
#               Suriname          199    199   170  SUR   Paramaribo
#               Peru              162    162    44  PER         Lima
#               Paraguay          161    161   109  PRY    AsunciÃ³n
# ...                             ...    ...   ...  ...          ...
# Africa        Burkina Faso       31     31    58  BFA  Ouagadougou
#               Botswana           26     26   144  BWA     Gaborone
#               Benin              21     21    77  BEN   Porto-Novo
#               Angola              5      5    42  AGO       Luanda
#               Algeria             2      2    34  DZA      Algiers
#
#                             2022 Population  2020 Population  2015 Population  \
# Continent     Country
# ...
